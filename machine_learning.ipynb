# %%
# implementing linear regression
import pandas as pd
import matplotlib.pyplot as plt
import os
import random

print(os.path.abspath('Medal.xlsx'))

data = pd.read_csv('Medals.csv')

data.rename(columns={"Team/NOC":"Country"}, inplace=True)
print(data.columns)

# plt.scatter(data.Gold, data.Silver)
# plt.xlabel = "Gold medals"
# plt.ylabel =  "Silver medals"
# plt.show()

def loss_function(m, b, points):
    total_error = 0
    for i in tange(len(points)):
        x = points.iloc[i].Gold
        y = points.iloc[i].Bronze
        total_error += (y - (m * x + b)) ** 2
        total_error / float(len(points))

def gradient_descent(m_now, b_now, points, L):
    m_gradient = 0
    b_gradient = 0

    n = len(points)
    for i in range(n):
         x = points.iloc[i].Gold
         y = points.iloc[i].Bronze

         m_gradient += -(2/n) * x * (y - (m_now * x + b_now))
         b_gradient += -(2/n) * (y - (m_now * x + b_now))
    
    m = m_now - m_gradient * L
    b = b_now - b_gradient * L
    return m, b

m = 0
b = 0
L = 0.0001
epochs = 100

for i in range(epochs):
    if i % 50 == 0:
        print(f"Epoch: {i}")
    m, b = gradient_descent(m, b, data, L)

print(m, b)

plt.scatter(data.Gold, data.Silver, color="red")
plt.plot(list(range(20, 80)), [m * x + b for x in range(20, 80)], color="black")
# plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File c:\Users\Latitude E7270\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\__init__.py:29, in <module>
#      28 try:
# ---> 29     from pandas._libs import hashtable as _hashtable, lib as _lib, tslib as _tslib
#      30 except ImportError as e:  # pragma: no cover
#      31     # hack but overkill to use re
#
# File c:\Users\Latitude E7270\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\__init__.py:13, in <module>
#       1 __all__ = [
#       2     "NaT",
#       3     "NaTType",
#    (...)
#       9     "Interval",
#      10 ]
# ---> 13 from pandas._libs.interval import Interval
#      14 from pandas._libs.tslibs import (
#      15     NaT,
#      16     NaTType,
#    (...)
#      21     iNaT,
#      22 )
#
# ModuleNotFoundError: No module named 'pandas._libs.interval'
#
# ...

# %%
# Implementing Simple Linear Regression
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model
import os

os.path.abspath("homeprices.csv")

df = pd.read_csv('c:\\Users\\Latitude E7270\\Documents\\Vscode files\\Datasets\\homeprices.csv')
df
df.plot(kind='scatter', x='area', y='price') # Matplotlib is built on top of pandas
# Out:
# Failed to start the Kernel.
#
# C:\Users\Latitude E7270\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\traitlets\traitlets.py:2392: FutureWarning: Supporting extra quotes around strings is deprecated in traitlets 5.0. You can use 'hmac-sha256' instead of '"hmac-sha256"' if you require traitlets >=5.
#
#   warn(
#
# C:\Users\Latitude E7270\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\traitlets\traitlets.py:2346: FutureWarning: Supporting extra quotes around Bytes is deprecated in traitlets 5.0. Use '7c5f27f5-5bd8-49a2-bbc1-7e23d6f7a443' instead of 'b"7c5f27f5-5bd8-49a2-bbc1-7e23d6f7a443"'.
#
#   warn(
#
# ...

# %%
# %matplotlib inline
plt.scatter(df.area, df.price, color="r", marker="*")
# plt.plot(df.area, reg.predict(df[['area']]), color="r")
plt.xlabel('area(sqr ft)', fontsize=10, color="g")
plt.ylabel('price(USD)', fontsize=10, color="g")
plt.title('Another random chart', fontsize=12, color="black")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Latitude E7270\Documents\Codes\Vscode files\Ipython files\machine_learning.ipynb Cell 3' in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Latitude%20E7270/Documents/Codes/Vscode%20files/Ipython%20files/machine_learning.ipynb#ch0000002?line=0'>1</a> # %matplotlib inline
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Latitude%20E7270/Documents/Codes/Vscode%20files/Ipython%20files/machine_learning.ipynb#ch0000002?line=1'>2</a> plt.scatter(df.area, df.price, color="r", marker="*")
#       <a href='vscode-notebook-cell:/c%3A/Users/Latitude%20E7270/Documents/Codes/Vscode%20files/Ipython%20files/machine_learning.ipynb#ch0000002?line=2'>3</a> # plt.plot(df.area, reg.predict(df[['area']]), color="r")
# ...

# %%
#Creating a linear regression object
reg = linear_model.LinearRegression()
# fit
model = reg.fit(df[['area']], df.price)
reg.predict([[round(5000, 2)]])
print(f"Coefficient: {reg.coef_}")
print(f"Intercept: {reg.intercept_}")

type(reg)
# Out:
# Coefficient: [135.78767123]
# Intercept: 180616.43835616432
# c:\Users\Latitude E7270\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# sklearn.linear_model._base.LinearRegression

# %%
import folium

# help(folium)
# dir(folium)

# %%
from sklearn.model_selection import cross_val_score
from sklearn.datasets import load_iris
from sklearn.linear_model import LogisticRegression
import pandas as pd
import numpy as np

#loading iris datasets from sklearn dataset module
iris = load_iris()

# Creating a Logistic regression model
logreg = linear_model.LogisticRegression()

# getting the accuracy score of the model using cross validation
scores = cross_val_score(logreg, iris.data, iris.target, cv=10)
scores

# Getting the mean of the the cross validation values 
scores_mean = scores.mean()
round(scores_mean, 2)

iris_df = pd.DataFrame(iris.data)
iris_df
# Out:
# c:\Users\Latitude E7270\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\Latitude E7270\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# ...

# %%
import sys
print("Python version: {}".format(sys.version))
import pandas as pd
print("pandas version: {}".format(pd.__version__))
import matplotlib
print("matplotlib version: {}".format(matplotlib.__version__))
import numpy as np
print("NumPy version: {}".format(np.__version__))
import scipy as sp
print("SciPy version: {}".format(sp.__version__))
import IPython
print("IPython version: {}".format(IPython.__version__))
import sklearn
print("scikit-learn version: {}".format(sklearn.__version__))
# Out:
# Python version: 3.9.2 (tags/v3.9.2:1a79785, Feb 19 2021, 13:44:55) [MSC v.1928 64 bit (AMD64)]
# pandas version: 1.2.4
# matplotlib version: 3.4.2
# NumPy version: 1.20.3
# SciPy version: 1.8.0
# IPython version: 7.24.1
# scikit-learn version: 1.0.2

# %%
import mglearn

x, y = mglearn.datasets.make_forge() # forclassification algorithms
x
mglearn.discrete_scatter(x[:, 0], x[:, 1], y)
plt.legend(["Class 0", "Class 1"], loc=4)
plt.xlabel("First feature")
plt.ylabel("Second feature")
# Out:
# c:\Users\Latitude E7270\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function make_blobs is deprecated; Please import make_blobs directly from scikit-learn
#   warnings.warn(msg, category=FutureWarning)
# Text(0, 0.5, 'Second feature')

# %%
# For regression algorithms

x, y = mglearn.datasets.make_wave(n_samples=40)
plt.plot(x, y, 'o', color='red')
plt.xlabel("Feature")
plt.ylabel("Target")
# Out:
# Text(0, 0.5, 'Target')

# %%
from sklearn.datasets import load_breast_cancer
cancer = load_breast_cancer()

type(cancer)

cancer.keys()
cancer.target.shape

{n: v for n, v in zip(cancer.target_names, np.bincount(cancer.target))}

cancer.feature_names
cancer.DESCR

# Importing Boston datasets for regression
from sklearn.datasets import load_boston
# boston = load_boston()

boston.feature_names
cancer.keys()
cancer.data.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14972\2428999915.py in <module>
#      16 # boston = load_boston()
#      17
# ---> 18 boston.feature_names
#      19 cancer.keys()
#      20 cancer.data.shape
#
# NameError: name 'boston' is not defined

# %%
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier

# create a classifier object
# clf = KNeighborsClassifier()
x_train, x_test, y_train, y_test = train_test_split(cancer.data, cancer.target, 
                                                    test_size=0.3,random_state=17)

x_train.shape

training_accuracy = []
test_accuracy = []
neighbors_settings = range(1, 11)

for n_neighbors in neighbors_settings:
    # build the model
    clf = KNeighborsClassifier(n_neighbors=n_neighbors)
    clf.fit(x_train, y_train)
    # record training set accuracy
    training_accuracy.append(clf.score(x_train, y_train))
    # record generalization error
    test_accuracy.append(clf.score(x_test, y_test))

print(training_accuracy)
print(test_accuracy)

plt.plot(neighbors_settings, training_accuracy, label='training accuracy')
plt.plot(neighbors_settings, test_accuracy, label='test accuracy')
plt.xlabel('n_neighbors')
plt.ylabel('accuracy')
plt.legend()
# Out:
# [1.0, 0.9723618090452262, 0.964824120603015, 0.9623115577889447, 0.9547738693467337, 0.949748743718593, 0.9472361809045227, 0.9522613065326633, 0.9422110552763819, 0.9472361809045227]
# [0.8888888888888888, 0.8947368421052632, 0.9064327485380117, 0.9064327485380117, 0.9239766081871345, 0.9239766081871345, 0.9239766081871345, 0.9239766081871345, 0.9239766081871345, 0.9298245614035088]

# %%
mglearn.plots.plot_knn_regression(n_neighbors=3)
mglearn()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14972\3006961940.py in <module>
#       1 mglearn.plots.plot_knn_regression(n_neighbors=3)
# ----> 2 mglearn()
#
# TypeError: 'module' object is not callable

# %%
import random as rd 
import matplotlib.pyplot as plt

position = 0
walk = [position]
steps = 1000

for x in range(steps):
    print(f"x = {x}")
    print('-----------')
    step = 1 if rd.randint(0, 1) else -1 # This is a tenary operatiom
    print(f"Step After {step}")
    print('-----------')
    position += step
    print(f"Position = {position}")
    print('-----------')
    print('-----------')
    walk.append(position)

plt.plot(walk[:100])
# Out:
# x = 0
# -----------
# Step After -1
# -----------
# Position = -1
# -----------
# -----------
# x = 1
# -----------
# Step After 1
# -----------
# Position = 0
# -----------
# -----------
# x = 2
# -----------
# Step After 1
# -----------
# Position = 1
# -----------
# -----------
# x = 3
# -----------
# Step After 1
# -----------
# Position = 2
# -----------
# -----------
# x = 4
# -----------
# Step After 1
# -----------
# Position = 3
# -----------
# -----------
# x = 5
# -----------
# Step After -1
# -----------
# Position = 2
# -----------
# -----------
# x = 6
# -----------
# Step After -1
# -----------
# Position = 1
# -----------
# -----------
# x = 7
# -----------
# Step After 1
# -----------
# Position = 2
# -----------
# -----------
# x = 8
# -----------
# Step After 1
# -----------
# Position = 3
# -----------
# -----------
# x = 9
# -----------
# Step After -1
# -----------
# Position = 2
# -----------
# -----------
# x = 10
# -----------
# Step After 1
# -----------
# ...
